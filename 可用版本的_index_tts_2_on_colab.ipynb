# %% [markdown]
# <a href="https://colab.research.google.com/github/10fen/weipyq/blob/main/%E5%8F%AF%E7%94%A8%E7%89%88%E6%9C%AC%E7%9A%84_index_tts_2_on_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 安装工具链
# %pip install uv
# !uv tool install "huggingface_hub[cli]"
# Out:
# Collecting uv
#   Downloading uv-0.8.17-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading uv-0.8.17-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 87.0 MB/s eta 0:00:00
# Installing collected packages: uv
# Successfully installed uv-0.8.17
# Resolved 17 packages in 76ms
# Prepared 17 packages in 134ms
# Installed 17 packages in 17ms
#  + certifi==2025.8.3
#  + charset-normalizer==3.4.3
#  + filelock==3.19.1
#  + fsspec==2025.9.0
#  + hf-xet==1.1.10
#  + huggingface-hub==0.34.4
#  + idna==3.10
#  + inquirerpy==0.3.4
#  + packaging==25.0
#  + pfzy==0.3.4
#  + prompt-toolkit==3.0.52
#  + pyyaml==6.0.2
#  + requests==2.32.5
#  + tqdm==4.67.1
#  + typing-extensions==4.15.0
#  + urllib3==2.5.0
#  + wcwidth==0.2.13
# Installed 3 executables: hf, huggingface-cli, tiny-agents
# warning: `/root/.local/bin` is not on your PATH. To use installed tools, run `export PATH="/root/.local/bin:$PATH"` or `uv tool update-shell`.

# %%
# 获取代码
# !wget https://github.com/index-tts/index-tts/archive/refs/heads/main.zip
# !unzip main.zip
# !mv index-tts-main index-tts
# !rm main.zip
# Out:
# --2025-09-14 15:28:24--  https://github.com/index-tts/index-tts/archive/refs/heads/main.zip
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/index-tts/index-tts/zip/refs/heads/main [following]
# --2025-09-14 15:28:24--  https://codeload.github.com/index-tts/index-tts/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 20.205.243.165
# Connecting to codeload.github.com (codeload.github.com)|20.205.243.165|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘main.zip’
#
# main.zip                [           <=>      ]  31.72M  12.2MB/s    in 2.6s
#
# 2025-09-14 15:28:27 (12.2 MB/s) - ‘main.zip’ saved [33259375]
#
# Archive:  main.zip
# 009428b62dc60b9d7bfdddd1641d51df9c2afa80
#    creating: index-tts-main/
#   inflating: index-tts-main/.gitattributes
#   inflating: index-tts-main/.gitignore
#  extracting: index-tts-main/.python-version
#   inflating: index-tts-main/DISCLAIMER
#   inflating: index-tts-main/LICENSE
#   inflating: index-tts-main/LICENSE_ZH.txt
#   inflating: index-tts-main/MANIFEST.in
#   inflating: index-tts-main/README.md
#    creating: index-tts-main/archive/
#   inflating: index-tts-main/archive/README_INDEXTTS_1_5.md
#    creating: index-tts-main/assets/
#   inflating: index-tts-main/assets/.DS_Store
#   inflating: index-tts-main/assets/IndexTTS.png
#   inflating: index-tts-main/assets/IndexTTS2-video-pic.png
#   inflating: index-tts-main/assets/IndexTTS2.mp4
#   inflating: index-tts-main/assets/IndexTTS2.png
#  extracting: index-tts-main/assets/IndexTTS2_banner.png
#   inflating: index-tts-main/assets/img.png
#   inflating: index-tts-main/assets/index_icon.png
#    creating: index-tts-main/checkpoints/
#   inflating: index-tts-main/checkpoints/config.yaml
#    creating: index-tts-main/docs/
#   inflating: index-tts-main/docs/README_zh.md
#    creating: index-tts-main/examples/
#   inflating: index-tts-main/examples/cases.jsonl
#   inflating: index-tts-main/examples/emo_hate.wav
#   inflating: index-tts-main/examples/emo_sad.wav
#   inflating: index-tts-main/examples/voice_01.wav
#   inflating: index-tts-main/examples/voice_02.wav
#   inflating: index-tts-main/examples/voice_03.wav
#   inflating: index-tts-main/examples/voice_04.wav
#   inflating: index-tts-main/examples/voice_05.wav
#   inflating: index-tts-main/examples/voice_06.wav
#   inflating: index-tts-main/examples/voice_07.wav
#   inflating: index-tts-main/examples/voice_08.wav
#   inflating: index-tts-main/examples/voice_09.wav
#   inflating: index-tts-main/examples/voice_10.wav
#   inflating: index-tts-main/examples/voice_11.wav
#   inflating: index-tts-main/examples/voice_12.wav
#    creating: index-tts-main/indextts/
#    creating: index-tts-main/indextts/BigVGAN/
#   inflating: index-tts-main/indextts/BigVGAN/ECAPA_TDNN.py
#  extracting: index-tts-main/indextts/BigVGAN/__init__.py
#   inflating: index-tts-main/indextts/BigVGAN/activations.py
#    creating: index-tts-main/indextts/BigVGAN/alias_free_activation/
#  extracting: index-tts-main/indextts/BigVGAN/alias_free_activation/__init__.py
#    creating: index-tts-main/indextts/BigVGAN/alias_free_activation/cuda/
#  extracting: index-tts-main/indextts/BigVGAN/alias_free_activation/cuda/.gitignore
#  extracting: index-tts-main/indextts/BigVGAN/alias_free_activation/cuda/__init__.py
#   inflating: index-tts-main/indextts/BigVGAN/alias_free_activation/cuda/activation1d.py
#   inflating: index-tts-main/indextts/BigVGAN/alias_free_activation/cuda/anti_alias_activation.cpp
#   inflating: index-tts-main/indextts/BigVGAN/alias_free_activation/cuda/anti_alias_activation_cuda.cu
#   inflating: index-tts-main/indextts/BigVGAN/alias_free_activation/cuda/compat.h
#   inflating: index-tts-main/indextts/BigVGAN/alias_free_activation/cuda/load.py
#   inflating: index-tts-main/indextts/BigVGAN/alias_free_activation/cuda/type_shim.h
#    creating: index-tts-main/indextts/BigVGAN/alias_free_activation/torch/
#   inflating: index-tts-main/indextts/BigVGAN/alias_free_activation/torch/__init__.py
#   inflating: index-tts-main/indextts/BigVGAN/alias_free_activation/torch/act.py
#   inflating: index-tts-main/indextts/BigVGAN/alias_free_activation/torch/filter.py
#   inflating: index-tts-main/indextts/BigVGAN/alias_free_activation/torch/resample.py
#    creating: index-tts-main/indextts/BigVGAN/alias_free_torch/
#   inflating: index-tts-main/indextts/BigVGAN/alias_free_torch/__init__.py
#   inflating: index-tts-main/indextts/BigVGAN/alias_free_torch/act.py
#   inflating: index-tts-main/indextts/BigVGAN/alias_free_torch/filter.py
#   inflating: index-tts-main/indextts/BigVGAN/alias_free_torch/resample.py
#   inflating: index-tts-main/indextts/BigVGAN/bigvgan.py
#   inflating: index-tts-main/indextts/BigVGAN/models.py
#    creating: index-tts-main/indextts/BigVGAN/nnet/
#   inflating: index-tts-main/indextts/BigVGAN/nnet/CNN.py
#  extracting: index-tts-main/indextts/BigVGAN/nnet/__init__.py
#   inflating: index-tts-main/indextts/BigVGAN/nnet/linear.py
#   inflating: index-tts-main/indextts/BigVGAN/nnet/normalization.py
#   inflating: index-tts-main/indextts/BigVGAN/utils.py
#  extracting: index-tts-main/indextts/__init__.py
#   inflating: index-tts-main/indextts/cli.py
#    creating: index-tts-main/indextts/gpt/
#  extracting: index-tts-main/indextts/gpt/__init__.py
#    creating: index-tts-main/indextts/gpt/conformer/
#  extracting: index-tts-main/indextts/gpt/conformer/__init__.py
#   inflating: index-tts-main/indextts/gpt/conformer/attention.py
#   inflating: index-tts-main/indextts/gpt/conformer/embedding.py
#   inflating: index-tts-main/indextts/gpt/conformer/subsampling.py
#   inflating: index-tts-main/indextts/gpt/conformer_encoder.py
#   inflating: index-tts-main/indextts/gpt/model.py
#   inflating: index-tts-main/indextts/gpt/model_v2.py
#   inflating: index-tts-main/indextts/gpt/perceiver.py
#   inflating: index-tts-main/indextts/gpt/transformers_beam_search.py
#   inflating: index-tts-main/indextts/gpt/transformers_generation_utils.py
#   inflating: index-tts-main/indextts/gpt/transformers_gpt2.py
#   inflating: index-tts-main/indextts/gpt/transformers_modeling_utils.py
#   inflating: index-tts-main/indextts/infer.py
#   inflating: index-tts-main/indextts/infer_v2.py
#    creating: index-tts-main/indextts/s2mel/
#    creating: index-tts-main/indextts/s2mel/dac/
#   inflating: index-tts-main/indextts/s2mel/dac/__init__.py
#   inflating: index-tts-main/indextts/s2mel/dac/__main__.py
#    creating: index-tts-main/indextts/s2mel/dac/model/
#   inflating: index-tts-main/indextts/s2mel/dac/model/__init__.py
#   inflating: index-tts-main/indextts/s2mel/dac/model/base.py
#   inflating: index-tts-main/indextts/s2mel/dac/model/dac.py
#   inflating: index-tts-main/indextts/s2mel/dac/model/discriminator.py
#   inflating: index-tts-main/indextts/s2mel/dac/model/encodec.py
#    creating: index-tts-main/indextts/s2mel/dac/nn/
#   inflating: index-tts-main/indextts/s2mel/dac/nn/__init__.py
#   inflating: index-tts-main/indextts/s2mel/dac/nn/layers.py
#   inflating: index-tts-main/indextts/s2mel/dac/nn/loss.py
#   inflating: index-tts-main/indextts/s2mel/dac/nn/quantize.py
#    creating: index-tts-main/indextts/s2mel/dac/utils/
#   inflating: index-tts-main/indextts/s2mel/dac/utils/__init__.py
#   inflating: index-tts-main/indextts/s2mel/dac/utils/decode.py
#   inflating: index-tts-main/indextts/s2mel/dac/utils/encode.py
#   inflating: index-tts-main/indextts/s2mel/hf_utils.py
#    creating: index-tts-main/indextts/s2mel/modules/
#    creating: index-tts-main/indextts/s2mel/modules/.ipynb_checkpoints/
#   inflating: index-tts-main/indextts/s2mel/modules/.ipynb_checkpoints/audio-checkpoint.py
#   inflating: index-tts-main/indextts/s2mel/modules/.ipynb_checkpoints/commons-checkpoint.py
#   inflating: index-tts-main/indextts/s2mel/modules/.ipynb_checkpoints/diffusion_transformer-checkpoint.py
#   inflating: index-tts-main/indextts/s2mel/modules/.ipynb_checkpoints/flow_matching-checkpoint.py
#   inflating: index-tts-main/indextts/s2mel/modules/.ipynb_checkpoints/length_regulator-checkpoint.py
#    creating: index-tts-main/indextts/s2mel/modules/alias_free_torch/
#   inflating: index-tts-main/indextts/s2mel/modules/alias_free_torch/__init__.py
#   inflating: index-tts-main/indextts/s2mel/modules/alias_free_torch/act.py
#   inflating: index-tts-main/indextts/s2mel/modules/alias_free_torch/filter.py
#   inflating: index-tts-main/indextts/s2mel/modules/alias_free_torch/resample.py
#   inflating: index-tts-main/indextts/s2mel/modules/audio.py
#    creating: index-tts-main/indextts/s2mel/modules/bigvgan/
#   inflating: index-tts-main/indextts/s2mel/modules/bigvgan/activations.py
#    creating: index-tts-main/indextts/s2mel/modules/bigvgan/alias_free_activation/
#    creating: index-tts-main/indextts/s2mel/modules/bigvgan/alias_free_activation/cuda/
#  extracting: index-tts-main/indextts/s2mel/modules/bigvgan/alias_free_activation/cuda/__init__.py
#   inflating: index-tts-main/indextts/s2mel/modules/bigvgan/alias_free_activation/cuda/activation1d.py
#   inflating: index-tts-main/indextts/s2mel/modules/bigvgan/alias_free_activation/cuda/anti_alias_activation.cpp
#   inflating: index-tts-main/indextts/s2mel/modules/bigvgan/alias_free_activation/cuda/anti_alias_activation_cuda.cu
#   inflating: index-tts-main/indextts/s2mel/modules/bigvgan/alias_free_activation/cuda/compat.h
#   inflating: index-tts-main/indextts/s2mel/modules/bigvgan/alias_free_activation/cuda/load.py
#   inflating: index-tts-main/indextts/s2mel/modules/bigvgan/alias_free_activation/cuda/type_shim.h
#    creating: index-tts-main/indextts/s2mel/modules/bigvgan/alias_free_activation/torch/
#   inflating: index-tts-main/indextts/s2mel/modules/bigvgan/alias_free_activation/torch/__init__.py
#   inflating: index-tts-main/indextts/s2mel/modules/bigvgan/alias_free_activation/torch/act.py
#   inflating: index-tts-main/indextts/s2mel/modules/bigvgan/alias_free_activation/torch/filter.py
#   inflating: index-tts-main/indextts/s2mel/modules/bigvgan/alias_free_activation/torch/resample.py
#   inflating: index-tts-main/indextts/s2mel/modules/bigvgan/bigvgan.py
#   inflating: index-tts-main/indextts/s2mel/modules/bigvgan/config.json
#   inflating: index-tts-main/indextts/s2mel/modules/bigvgan/env.py
#   inflating: index-tts-main/indextts/s2mel/modules/bigvgan/meldataset.py
#   inflating: index-tts-main/indextts/s2mel/modules/bigvgan/utils.py
#    creating: index-tts-main/indextts/s2mel/modules/campplus/
#   inflating: index-tts-main/indextts/s2mel/modules/campplus/DTDNN.py
#   inflating: index-tts-main/indextts/s2mel/modules/campplus/classifier.py
#   inflating: index-tts-main/indextts/s2mel/modules/campplus/layers.py
#   inflating: index-tts-main/indextts/s2mel/modules/commons.py
#   inflating: index-tts-main/indextts/s2mel/modules/diffusion_transformer.py
#   inflating: index-tts-main/indextts/s2mel/modules/encodec.py
#   inflating: index-tts-main/indextts/s2mel/modules/flow_matching.py
#    creating: index-tts-main/indextts/s2mel/modules/gpt_fast/
#    creating: index-tts-main/indextts/s2mel/modules/gpt_fast/.ipynb_checkpoints/
#   inflating: index-tts-main/indextts/s2mel/modules/gpt_fast/.ipynb_checkpoints/model-checkpoint.py
#   inflating: index-tts-main/indextts/s2mel/modules/gpt_fast/generate.py
#   inflating: index-tts-main/indextts/s2mel/modules/gpt_fast/model.py
#   inflating: index-tts-main/indextts/s2mel/modules/gpt_fast/quantize.py
#    creating: index-tts-main/indextts/s2mel/modules/hifigan/
#   inflating: index-tts-main/indextts/s2mel/modules/hifigan/f0_predictor.py
#   inflating: index-tts-main/indextts/s2mel/modules/hifigan/generator.py
#   inflating: index-tts-main/indextts/s2mel/modules/layers.py
#   inflating: index-tts-main/indextts/s2mel/modules/length_regulator.py
#    creating: index-tts-main/indextts/s2mel/modules/openvoice/
#  extracting: index-tts-main/indextts/s2mel/modules/openvoice/__init__.py
#   inflating: index-tts-main/indextts/s2mel/modules/openvoice/api.py
#   inflating: index-tts-main/indextts/s2mel/modules/openvoice/attentions.py
#    creating: index-tts-main/indextts/s2mel/modules/openvoice/checkpoints_v2/
#    creating: index-tts-main/indextts/s2mel/modules/openvoice/checkpoints_v2/converter/
#   inflating: index-tts-main/indextts/s2mel/modules/openvoice/checkpoints_v2/converter/config.json
#   inflating: index-tts-main/indextts/s2mel/modules/openvoice/commons.py
#   inflating: index-tts-main/indextts/s2mel/modules/openvoice/mel_processing.py
#   inflating: index-tts-main/indextts/s2mel/modules/openvoice/models.py
#   inflating: index-tts-main/indextts/s2mel/modules/openvoice/modules.py
#   inflating: index-tts-main/indextts/s2mel/modules/openvoice/openvoice_app.py
#   inflating: index-tts-main/indextts/s2mel/modules/openvoice/se_extractor.py
#   inflating: index-tts-main/indextts/s2mel/modules/openvoice/transforms.py
#   inflating: index-tts-main/indextts/s2mel/modules/openvoice/utils.py
#   inflating: index-tts-main/indextts/s2mel/modules/quantize.py
#   inflating: index-tts-main/indextts/s2mel/modules/rmvpe.py
#    creating: index-tts-main/indextts/s2mel/modules/vocos/
#  extracting: index-tts-main/indextts/s2mel/modules/vocos/__init__.py
#   inflating: index-tts-main/indextts/s2mel/modules/vocos/heads.py
#   inflating: index-tts-main/indextts/s2mel/modules/vocos/helpers.py
#   inflating: index-tts-main/indextts/s2mel/modules/vocos/loss.py
#   inflating: index-tts-main/indextts/s2mel/modules/vocos/models.py
#   inflating: index-tts-main/indextts/s2mel/modules/vocos/modules.py
#   inflating: index-tts-main/indextts/s2mel/modules/vocos/pretrained.py
#   inflating: index-tts-main/indextts/s2mel/modules/vocos/spectral_ops.py
#   inflating: index-tts-main/indextts/s2mel/modules/wavenet.py
#   inflating: index-tts-main/indextts/s2mel/optimizers.py
#   inflating: index-tts-main/indextts/s2mel/wav2vecbert_extract.py
#    creating: index-tts-main/indextts/utils/
#  extracting: index-tts-main/indextts/utils/__init__.py
#   inflating: index-tts-main/indextts/utils/arch_util.py
#   inflating: index-tts-main/indextts/utils/checkpoint.py
#   inflating: index-tts-main/indextts/utils/common.py
#   inflating: index-tts-main/indextts/utils/feature_extractors.py
#   inflating: index-tts-main/indextts/utils/front.py
#    creating: index-tts-main/indextts/utils/maskgct/
#    creating: index-tts-main/indextts/utils/maskgct/models/
#    creating: index-tts-main/indextts/utils/maskgct/models/codec/
#  extracting: index-tts-main/indextts/utils/maskgct/models/codec/__init__.py
#    creating: index-tts-main/indextts/utils/maskgct/models/codec/amphion_codec/
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/amphion_codec/codec.py
#    creating: index-tts-main/indextts/utils/maskgct/models/codec/amphion_codec/quantize/
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/amphion_codec/quantize/__init__.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/amphion_codec/quantize/factorized_vector_quantize.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/amphion_codec/quantize/lookup_free_quantize.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/amphion_codec/quantize/residual_vq.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/amphion_codec/quantize/vector_quantize.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/amphion_codec/vocos.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/codec_dataset.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/codec_inference.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/codec_sampler.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/codec_trainer.py
#    creating: index-tts-main/indextts/utils/maskgct/models/codec/facodec/
#  extracting: index-tts-main/indextts/utils/maskgct/models/codec/facodec/__init__.py
#    creating: index-tts-main/indextts/utils/maskgct/models/codec/facodec/alias_free_torch/
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/facodec/alias_free_torch/__init__.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/facodec/alias_free_torch/act.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/facodec/alias_free_torch/filter.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/facodec/alias_free_torch/resample.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/facodec/facodec_dataset.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/facodec/facodec_inference.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/facodec/facodec_trainer.py
#    creating: index-tts-main/indextts/utils/maskgct/models/codec/facodec/modules/
#    creating: index-tts-main/indextts/utils/maskgct/models/codec/facodec/modules/JDC/
#  extracting: index-tts-main/indextts/utils/maskgct/models/codec/facodec/modules/JDC/__init__.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/facodec/modules/JDC/bst.t7
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/facodec/modules/JDC/model.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/facodec/modules/attentions.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/facodec/modules/commons.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/facodec/modules/gradient_reversal.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/facodec/modules/layers.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/facodec/modules/quantize.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/facodec/modules/style_encoder.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/facodec/modules/wavenet.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/facodec/optimizer.py
#    creating: index-tts-main/indextts/utils/maskgct/models/codec/kmeans/
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/kmeans/repcodec_model.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/kmeans/vocos.py
#    creating: index-tts-main/indextts/utils/maskgct/models/codec/melvqgan/
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/melvqgan/melspec.py
#    creating: index-tts-main/indextts/utils/maskgct/models/codec/ns3_codec/
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/ns3_codec/README.md
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/ns3_codec/__init__.py
#    creating: index-tts-main/indextts/utils/maskgct/models/codec/ns3_codec/alias_free_torch/
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/ns3_codec/alias_free_torch/__init__.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/ns3_codec/alias_free_torch/act.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/ns3_codec/alias_free_torch/filter.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/ns3_codec/alias_free_torch/resample.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/ns3_codec/facodec.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/ns3_codec/gradient_reversal.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/ns3_codec/melspec.py
#    creating: index-tts-main/indextts/utils/maskgct/models/codec/ns3_codec/quantize/
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/ns3_codec/quantize/__init__.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/ns3_codec/quantize/fvq.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/ns3_codec/quantize/rvq.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/ns3_codec/transformer.py
#    creating: index-tts-main/indextts/utils/maskgct/models/codec/speechtokenizer/
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/speechtokenizer/model.py
#    creating: index-tts-main/indextts/utils/maskgct/models/codec/speechtokenizer/modules/
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/speechtokenizer/modules/__init__.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/speechtokenizer/modules/conv.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/speechtokenizer/modules/lstm.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/speechtokenizer/modules/norm.py
#    creating: index-tts-main/indextts/utils/maskgct/models/codec/speechtokenizer/modules/quantization/
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/speechtokenizer/modules/quantization/__init__.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/speechtokenizer/modules/quantization/ac.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/speechtokenizer/modules/quantization/core_vq.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/speechtokenizer/modules/quantization/distrib.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/speechtokenizer/modules/quantization/vq.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/speechtokenizer/modules/seanet.py
#    creating: index-tts-main/indextts/utils/maskgct/models/codec/vevo/
#   inflating: index-tts-main/indextts/utils/maskgct/models/codec/vevo/vevo_repcodec.py
#    creating: index-tts-main/indextts/utils/maskgct/models/tts/
#    creating: index-tts-main/indextts/utils/maskgct/models/tts/maskgct/
#    creating: index-tts-main/indextts/utils/maskgct/models/tts/maskgct/ckpt/
#   inflating: index-tts-main/indextts/utils/maskgct/models/tts/maskgct/ckpt/wav2vec2bert_stats.pt
#   inflating: index-tts-main/indextts/utils/maskgct/models/tts/maskgct/llama_nar.py
#   inflating: index-tts-main/indextts/utils/maskgct/models/tts/maskgct/maskgct_s2a.py
#   inflating: index-tts-main/indextts/utils/maskgct_utils.py
#   inflating: index-tts-main/indextts/utils/text_utils.py
#   inflating: index-tts-main/indextts/utils/typical_sampling.py
#   inflating: index-tts-main/indextts/utils/utils.py
#   inflating: index-tts-main/indextts/utils/webui_utils.py
#   inflating: index-tts-main/indextts/utils/xtransformers.py
#    creating: index-tts-main/indextts/vqvae/
#  extracting: index-tts-main/indextts/vqvae/__init__.py
#   inflating: index-tts-main/indextts/vqvae/xtts_dvae.py
#   inflating: index-tts-main/pyproject.toml
#    creating: index-tts-main/tests/
#   inflating: index-tts-main/tests/cases.jsonl
#   inflating: index-tts-main/tests/padding_test.py
#   inflating: index-tts-main/tests/regression_test.py
#   inflating: index-tts-main/tests/sample_prompt.wav
#    creating: index-tts-main/tools/
#   inflating: index-tts-main/tools/gpu_check.py
#    creating: index-tts-main/tools/i18n/
#   inflating: index-tts-main/tools/i18n/i18n.py
#    creating: index-tts-main/tools/i18n/locale/
#   inflating: index-tts-main/tools/i18n/locale/en_US.json
#   inflating: index-tts-main/tools/i18n/locale/zh_CN.json
#   inflating: index-tts-main/tools/i18n/scan_i18n.py
#   inflating: index-tts-main/uv.lock
#   inflating: index-tts-main/webui.py

# %%
# 安装依赖
# !cd /content/index-tts/ && uv sync --all-extras
# Out:
# Using CPython 3.10.12 interpreter at: /usr/bin/python3.10
# Creating virtual environment at: .venv
# Resolved 190 packages in 1ms
# Prepared 178 packages in 1m 30s
# Installed 178 packages in 1.23s
# Prepared 1 package without build isolation in 32.64s
# Installed 1 package in 21ms
#  + absl-py==2.3.1
#  + accelerate==1.8.1
#  + aiofiles==24.1.0
#  + annotated-types==0.7.0
#  + antlr4-python3-runtime==4.9.3
#  + anyio==4.10.0
#  + argbind==0.3.9
#  + asttokens==3.0.0
#  + audioread==3.0.1
#  + brotli==1.1.0
#  + cachetools==5.5.2
#  + certifi==2025.8.3
#  + cffi==2.0.0
#  + charset-normalizer==3.4.3
#  + click==8.2.1
#  + cn2an==0.5.22
#  + contourpy==1.3.2
#  + cycler==0.12.1
#  + cython==3.0.7
#  + decorator==5.2.1
#  + deepspeed==0.17.1
#  + descript-audiotools==0.7.2
#  + distance==0.1.3
#  + docstring-parser==0.17.0
#  + einops==0.8.1
#  + exceptiongroup==1.3.0
#  + executing==2.2.1
#  + fastapi==0.116.1
#  + ffmpeg-python==0.2.0
#  + ffmpy==0.6.1
#  + filelock==3.19.1
#  + fire==0.7.1
#  + flatten-dict==0.4.2
#  + fonttools==4.59.2
#  + fsspec==2025.9.0
#  + future==1.0.0
#  + g2p-en==2.1.0
#  + google-auth==2.40.3
#  + google-auth-oauthlib==0.4.6
#  + gradio==5.44.1
#  + gradio-client==1.12.1
#  + groovy==0.1.2
#  + grpcio==1.74.0
#  + h11==0.16.0
#  + hf-xet==1.1.9
#  + hjson==3.1.0
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + huggingface-hub==0.34.4
#  + idna==3.10
#  + importlib-resources==6.5.2
#  + indextts==2.0.0 (from file:///content/index-tts)
#  + inflect==7.5.0
#  + ipython==8.37.0
#  + jedi==0.19.2
#  + jieba==0.42.1
#  + jinja2==3.1.6
#  + joblib==1.5.2
#  + json5==0.10.0
#  + julius==0.2.7
#  + keras==2.9.0
#  + kiwisolver==1.4.9
#  + lazy-loader==0.4
#  + librosa==0.10.2.post1
#  + llvmlite==0.41.1
#  + markdown==3.9
#  + markdown-it-py==4.0.0
#  + markdown2==2.5.4
#  + markupsafe==3.0.2
#  + matplotlib==3.8.2
#  + matplotlib-inline==0.1.7
#  + mdurl==0.1.2
#  + modelscope==1.27.0
#  + more-itertools==10.8.0
#  + mpmath==1.3.0
#  + msgpack==1.1.1
#  + munch==4.0.0
#  + networkx==3.4.2
#  + ninja==1.13.0
#  + nltk==3.9.1
#  + numba==0.58.1
#  + numpy==1.26.2
#  + nvidia-cublas-cu12==12.8.4.1
#  + nvidia-cuda-cupti-cu12==12.8.90
#  + nvidia-cuda-nvrtc-cu12==12.8.93
#  + nvidia-cuda-runtime-cu12==12.8.90
#  + nvidia-cudnn-cu12==9.10.2.21
#  + nvidia-cufft-cu12==11.3.3.83
#  + nvidia-cufile-cu12==1.13.1.3
#  + nvidia-curand-cu12==10.3.9.90
#  + nvidia-cusolver-cu12==11.7.3.90
#  + nvidia-cusparse-cu12==12.5.8.93
#  + nvidia-cusparselt-cu12==0.7.1
#  + nvidia-nccl-cu12==2.27.3
#  + nvidia-nvjitlink-cu12==12.8.93
#  + nvidia-nvtx-cu12==12.8.90
#  + oauthlib==3.3.1
#  + omegaconf==2.3.0
#  + opencv-python==4.9.0.80
#  + orjson==3.11.3
#  + packaging==25.0
#  + pandas==2.3.2
#  + parso==0.8.5
#  + pexpect==4.9.0
#  + pillow==11.3.0
#  + platformdirs==4.4.0
#  + pooch==1.8.2
#  + proces==0.1.7
#  + prompt-toolkit==3.0.52
#  + protobuf==3.19.6
#  + psutil==7.0.0
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + py-cpuinfo==9.0.0
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.2
#  + pycparser==2.23
#  + pydantic==2.11.7
#  + pydantic-core==2.33.2
#  + pydub==0.25.1
#  + pygments==2.19.2
#  + pyloudnorm==0.1.1
#  + pynini==2.1.6
#  + pyparsing==3.2.3
#  + pyphen==0.17.2
#  + pystoi==0.4.1
#  + python-dateutil==2.9.0.post0
#  + python-multipart==0.0.20
#  + pytz==2025.2
#  + pyyaml==6.0.2
#  + randomname==0.2.1
#  + regex==2025.9.1
#  + requests==2.32.5
#  + requests-oauthlib==2.0.0
#  + rich==14.1.0
#  + rsa==4.9.1
#  + ruff==0.13.0
#  + safehttpx==0.1.6
#  + safetensors==0.5.2
#  + scikit-learn==1.7.2
#  + scipy==1.15.3
#  + semantic-version==2.10.0
#  + sentencepiece==0.2.1
#  + setuptools==80.9.0
#  + shellingham==1.5.4
#  + six==1.17.0
#  + sniffio==1.3.1
#  + soundfile==0.13.1
#  + soxr==1.0.0
#  + stack-data==0.6.3
#  + starlette==0.47.3
#  + sympy==1.14.0
#  + tensorboard==2.9.1
#  + tensorboard-data-server==0.6.1
#  + tensorboard-plugin-wit==1.8.1
#  + termcolor==3.1.0
#  + textstat==0.7.10
#  + threadpoolctl==3.6.0
#  + tokenizers==0.21.0
#  + tomlkit==0.13.3
#  + torch==2.8.0+cu128
#  + torch-stoi==0.2.3
#  + torchaudio==2.8.0+cu128
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + transformers==4.52.1
#  + triton==3.4.0
#  + typeguard==4.4.4
#  + typer==0.17.4
#  + typing-extensions==4.15.0
#  + typing-inspection==0.4.1
#  + tzdata==2025.2
#  + urllib3==2.5.0
#  + uvicorn==0.35.0
#  + wcwidth==0.2.13
#  + websockets==15.0.1
#  + werkzeug==3.1.3
#  + wetextprocessing==1.0.4.1
#  + wheel==0.45.1

# %%
# 下载模型 checkpoints
# !hf download IndexTeam/IndexTTS-2 --local-dir=/content/index-tts/checkpoints
# Out:
# Fetching 20 files:   0% 0/20 [00:00<?, ?it/s]Downloading 'feat1.pt' to '/content/index-tts/checkpoints/.cache/huggingface/download/MKSxOKdeAa3yNVriUN75BCpdwis=.f219cb447d80216ba615666da2ff8d63ac544eee26657f3a7b278692bf7a67c4.incomplete'
# Downloading 'gpt.pth' to '/content/index-tts/checkpoints/.cache/huggingface/download/_7f-xidG2lZwkbGRwdGaUEGM9-w=.baaaeb8b56328da81731dc540a85a7dee32eca9da28f174b05757cb651c602a4.incomplete'
# Downloading 'README.md' to '/content/index-tts/checkpoints/.cache/huggingface/download/Xn7B-BWUGOee2Y6hCZtEhtFu4BE=.cd4c8069c902205bed95cba5b28fe9986e74139e.incomplete'
# Downloading 'bpe.model' to '/content/index-tts/checkpoints/.cache/huggingface/download/Gxtyhw1DNb_863rgFQ-g37D7LQI=.b2a5ce8090d32da3642cc4f81fdc996376bc6dd3f4cd5e3d165f71120d9f2bc8.incomplete'
# Downloading 'feat2.pt' to '/content/index-tts/checkpoints/.cache/huggingface/download/jhr_Oe-8eUDBi3ePfijGwmdsvlE=.9c4292e96dee535aea9a6206e9a0c856dd578dde9212acdb16dd3ada4d12bf80.incomplete'
#
# README.md: 0.00B [00:00, ?B/s]Downloading 'config.yaml' to '/content/index-tts/checkpoints/.cache/huggingface/download/_ouC4VcfA9-o6nAiMaExMJW7X2A=.98d16c3892bd2321e7da71a379ecc8e1fa4dd84e.incomplete'
# README.md: 2.50kB [00:00, 2.50MB/s]
# Downloading 'qwen0.6bemo4-merge/Modelfile' to '/content/index-tts/checkpoints/.cache/huggingface/download/qwen0.6bemo4-merge/-T10lO8x1ud2PVxfECgsRvh55vU=.b1bed86c7c360343f16d4580b7fb6a19182da273.incomplete'
# Download complete. Moving file to /content/index-tts/checkpoints/README.md
# Downloading '.gitattributes' to '/content/index-tts/checkpoints/.cache/huggingface/download/wPaCkH-WbT7GsmxMKKrNZTV4nSM=.509a0d76a611e809c0fa4f66f284af575268eca1.incomplete'
#
# config.yaml: 0.00B [00:00, ?B/s]
#
# Modelfile: 100% 360/360 [00:00<00:00, 3.34MB/s]
# config.yaml: 2.88kB [00:00, 2.32MB/s]
# Download complete. Moving file to /content/index-tts/checkpoints/config.yaml
# Download complete. Moving file to /content/index-tts/checkpoints/qwen0.6bemo4-merge/Modelfile
#
# .gitattributes: 1.73kB [00:00, 4.01MB/s]
# Download complete. Moving file to /content/index-tts/checkpoints/.gitattributes
# Fetching 20 files:   5% 1/20 [00:00<00:06,  3.10it/s]
# feat2.pt:   0% 0.00/375k [00:00<?, ?B/s]
#
# bpe.model:   0% 0.00/476k [00:00<?, ?B/s]
#
#
# feat1.pt:   0% 0.00/57.2k [00:00<?, ?B/s]Downloading 'qwen0.6bemo4-merge/chat_template.jinja' to '/content/index-tts/checkpoints/.cache/huggingface/download/qwen0.6bemo4-merge/yIUQ6Jg7XpBWXEkozaEkS2ih05g=.d153f82f7ba7ddc6bfb46217304f0b5c8cc96044.incomplete'
#
#
#
#
# chat_template.jinja: 100% 550/550 [00:00<00:00, 3.72MB/s]
# Download complete. Moving file to /content/index-tts/checkpoints/qwen0.6bemo4-merge/chat_template.jinja
# Downloading 'qwen0.6bemo4-merge/config.json' to '/content/index-tts/checkpoints/.cache/huggingface/download/qwen0.6bemo4-merge/8_PA_wEVGiVa2goH2H4KQOQpvVY=.2b9955706f283df53046c7eaa9bc4137139c11aa.incomplete'
# Downloading 'qwen0.6bemo4-merge/generation_config.json' to '/content/index-tts/checkpoints/.cache/huggingface/download/qwen0.6bemo4-merge/3EVKVggOldJcKSsGjSdoUCN1AyQ=.520e468ea8345d57d70ba673ca62c2056c3c616b.incomplete'
#
#
#
#
# config.json: 100% 727/727 [00:00<00:00, 6.60MB/s]
# Download complete. Moving file to /content/index-tts/checkpoints/qwen0.6bemo4-merge/config.json
#
#
#
#
# generation_config.json: 100% 117/117 [00:00<00:00, 1.06MB/s]
# Download complete. Moving file to /content/index-tts/checkpoints/qwen0.6bemo4-merge/generation_config.json
# Downloading 'qwen0.6bemo4-merge/model.safetensors' to '/content/index-tts/checkpoints/.cache/huggingface/download/qwen0.6bemo4-merge/xGOKKLRSlIhH692hSVvI1-gpoa8=.11293257a8df593c154a8ecd5fc039f3076de35411e35f06d41b471e136f6641.incomplete'
# Downloading 'qwen0.6bemo4-merge/special_tokens_map.json' to '/content/index-tts/checkpoints/.cache/huggingface/download/qwen0.6bemo4-merge/ahkChHUJFxEmOdq5GDFEmerRzCY=.17305b3603dfb19ccc0f658ec2cd2cd3adff4a58.incomplete'
#
#
#
#
# special_tokens_map.json: 100% 616/616 [00:00<00:00, 6.32MB/s]
# Download complete. Moving file to /content/index-tts/checkpoints/qwen0.6bemo4-merge/special_tokens_map.json
#
#
#
#
# gpt.pth:   0% 0.00/3.48G [00:00<?, ?B/s]Downloading 'qwen0.6bemo4-merge/added_tokens.json' to '/content/index-tts/checkpoints/.cache/huggingface/download/qwen0.6bemo4-merge/SeqzFlf9ZNZ3or_wZAOIdsM3Yxw=.b54f9135e44c1e81047e8d05cb027af8bc039eed.incomplete'
#
#
#
#
#
# added_tokens.json: 100% 707/707 [00:00<00:00, 6.63MB/s]
# Download complete. Moving file to /content/index-tts/checkpoints/qwen0.6bemo4-merge/added_tokens.json
#
#
#
#
#
# qwen0.6bemo4-merge/model.safetensors:   0% 0.00/1.19G [00:00<?, ?B/s]Downloading 'qwen0.6bemo4-merge/tokenizer.json' to '/content/index-tts/checkpoints/.cache/huggingface/download/qwen0.6bemo4-merge/HgM_lKo9sdSCfRtVg7MMFS7EKqo=.aeb13307a71acd8fe81861d94ad54ab689df773318809eed3cbe794b4492dae4.incomplete'
# Downloading 'qwen0.6bemo4-merge/tokenizer_config.json' to '/content/index-tts/checkpoints/.cache/huggingface/download/qwen0.6bemo4-merge/vzaExXFZNBay89bvlQv-ZcI6BTg=.275ab4b74f4d4206ca5dcb2213961d380063ffb2.incomplete'
#
#
#
#
#
#
# tokenizer_config.json: 5.43kB [00:00, 22.0MB/s]
# Download complete. Moving file to /content/index-tts/checkpoints/qwen0.6bemo4-merge/tokenizer_config.json
# Downloading 'qwen0.6bemo4-merge/merges.txt' to '/content/index-tts/checkpoints/.cache/huggingface/download/qwen0.6bemo4-merge/PtHk0z_I45atnj23IIRhTExwT3w=.31349551d90c7606f325fe0f11bbb8bd5fa0d7c7.incomplete'
#
#
#
#
#
#
# merges.txt: 1.67MB [00:00, 87.5MB/s]
# Download complete. Moving file to /content/index-tts/checkpoints/qwen0.6bemo4-merge/merges.txt
#
#
#
#
#
#
# qwen0.6bemo4-merge/tokenizer.json:   0% 0.00/11.4M [00:00<?, ?B/s]Downloading 'qwen0.6bemo4-merge/vocab.json' to '/content/index-tts/checkpoints/.cache/huggingface/download/qwen0.6bemo4-merge/j3m-Hy6QvBddw8RXA1uSWl1AJ0c=.4783fe10ac3adce15ac8f358ef5462739852c569.incomplete'
#
#
#
#
#
#
#
# vocab.json: 2.78MB [00:00, 111MB/s]
# Download complete. Moving file to /content/index-tts/checkpoints/qwen0.6bemo4-merge/vocab.json
# Downloading 'wav2vec2bert_stats.pt' to '/content/index-tts/checkpoints/.cache/huggingface/download/Wr97nwTDtgqFqpd-NG3mhBUYIcc=.c9c176c2b8850ab2e3ba828bbfa969deaf4566ce55db5f2687b8430b87526ad2.incomplete'
#
# feat2.pt: 100% 375k/375k [00:01<00:00, 280kB/s]
# Download complete. Moving file to /content/index-tts/checkpoints/feat2.pt
#
#
# bpe.model: 100% 476k/476k [00:01<00:00, 340kB/s]
# Download complete. Moving file to /content/index-tts/checkpoints/bpe.model
# Fetching 20 files:  15% 3/20 [00:01<00:11,  1.46it/s]Downloading 's2mel.pth' to '/content/index-tts/checkpoints/.cache/huggingface/download/y-OKxzfe9YyclJ0KMAWtWN0NDX8=.aae1bb12017cbb47e7a5ce537fc82f40b6b1deb71acdb9b8f25686f32714b636.incomplete'
#
# wav2vec2bert_stats.pt:   0% 0.00/9.34k [00:00<?, ?B/s]
#
#
# feat1.pt: 100% 57.2k/57.2k [00:01<00:00, 38.6kB/s]
# Download complete. Moving file to /content/index-tts/checkpoints/feat1.pt
#
#
#
#
#
#
# qwen0.6bemo4-merge/tokenizer.json: 100% 11.4M/11.4M [00:00<00:00, 15.1MB/s]
# Download complete. Moving file to /content/index-tts/checkpoints/qwen0.6bemo4-merge/tokenizer.json
#
#
# s2mel.pth:   0% 0.00/1.20G [00:00<?, ?B/s]
# wav2vec2bert_stats.pt: 100% 9.34k/9.34k [00:00<00:00, 15.7kB/s]
# Download complete. Moving file to /content/index-tts/checkpoints/wav2vec2bert_stats.pt
#
#
#
#
# gpt.pth:   0% 663k/3.48G [00:01<2:45:13, 351kB/s]
#
#
#
#
# qwen0.6bemo4-merge/model.safetensors:   6% 67.0M/1.19G [00:02<00:33, 33.4MB/s]
#
#
#
# gpt.pth:   0% 2.11M/3.48G [00:02<52:38, 1.10MB/s]
#
#
#
#
# qwen0.6bemo4-merge/model.safetensors:   6% 76.4M/1.19G [00:03<00:57, 19.3MB/s]
#
#
#
#
# qwen0.6bemo4-merge/model.safetensors:   8% 101M/1.19G [00:06<01:19, 13.7MB/s]
#
#
#
#
# qwen0.6bemo4-merge/model.safetensors:  12% 144M/1.19G [00:08<01:08, 15.2MB/s]
#
#
#
#
# qwen0.6bemo4-merge/model.safetensors:  16% 186M/1.19G [00:08<00:41, 24.1MB/s]
#
#
#
#
# qwen0.6bemo4-merge/model.safetensors:  21% 253M/1.19G [00:12<00:42, 21.9MB/s]
#
#
#
# gpt.pth:   2% 69.2M/3.48G [00:12<09:24, 6.05MB/s]
#
#
#
# gpt.pth:   4% 136M/3.48G [00:12<04:06, 13.6MB/s]
#
#
#
#
# qwen0.6bemo4-merge/model.safetensors:  27% 321M/1.19G [00:15<00:42, 20.7MB/s]
#
#
#
# gpt.pth:   6% 203M/3.48G [00:15<03:16, 16.7MB/s]
#
#
#
# gpt.pth:   8% 270M/3.48G [00:16<02:07, 25.2MB/s]
#
# s2mel.pth:   0% 36.8k/1.20G [00:15<137:43:11, 2.42kB/s]
#
#
#
# gpt.pth:  12% 404M/3.48G [00:17<01:08, 44.9MB/s]
#
#
#
#
# qwen0.6bemo4-merge/model.safetensors:  33% 388M/1.19G [00:17<00:31, 25.5MB/s]
#
#
#
# gpt.pth:  14% 472M/3.48G [00:19<01:21, 37.0MB/s]
#
#
#
#
# qwen0.6bemo4-merge/model.safetensors:  38% 455M/1.19G [00:19<00:28, 25.6MB/s]
#
#
#
# gpt.pth:  15% 539M/3.48G [00:20<01:05, 44.8MB/s]
#
#
#
#
# qwen0.6bemo4-merge/model.safetensors:  44% 522M/1.19G [00:20<00:20, 32.9MB/s]
#
#
#
# gpt.pth:  17% 606M/3.48G [00:21<00:59, 48.1MB/s]
#
#
#
#
# qwen0.6bemo4-merge/model.safetensors:  49% 589M/1.19G [00:21<00:15, 38.2MB/s]
#
#
#
# gpt.pth:  19% 673M/3.48G [00:22<00:52, 53.3MB/s]
#
#
#
#
# qwen0.6bemo4-merge/model.safetensors:  55% 656M/1.19G [00:23<00:12, 43.4MB/s]
#
#
#
# gpt.pth:  21% 740M/3.48G [00:26<01:16, 35.9MB/s]
#
#
#
#
# qwen0.6bemo4-merge/model.safetensors:  61% 723M/1.19G [00:26<00:15, 30.4MB/s]
#
#
#
# gpt.pth:  25% 873M/3.48G [00:26<00:46, 56.3MB/s]
#
#
#
#
# qwen0.6bemo4-merge/model.safetensors:  66% 790M/1.19G [00:27<00:11, 35.4MB/s]
#
# s2mel.pth:   0% 55.5k/1.20G [00:26<167:02:44, 2.00kB/s]
#
#
#
#
# qwen0.6bemo4-merge/model.safetensors:  72% 857M/1.19G [00:28<00:07, 42.1MB/s]
#
#
#
# gpt.pth:  27% 940M/3.48G [00:28<00:53, 47.5MB/s]
#
#
#
# gpt.pth:  31% 1.07G/3.48G [00:29<00:31, 77.0MB/s]
#
# s2mel.pth:   0% 1.96M/1.20G [00:28<2:53:06, 116kB/s]
#
#
#
#
# qwen0.6bemo4-merge/model.safetensors:  77% 924M/1.19G [00:29<00:05, 48.8MB/s]
#
# s2mel.pth:   0% 3.99M/1.20G [00:28<1:12:34, 275kB/s]
#
#
#
# gpt.pth:  33% 1.14G/3.48G [00:30<00:34, 67.6MB/s]
#
#
#
#
# qwen0.6bemo4-merge/model.safetensors:  83% 991M/1.19G [00:30<00:03, 53.4MB/s]
#
#
#
# gpt.pth:  35% 1.21G/3.48G [00:31<00:34, 66.7MB/s]
#
# s2mel.pth:   0% 4.92M/1.20G [00:30<1:03:00, 317kB/s]
#
#
#
#
# qwen0.6bemo4-merge/model.safetensors:  89% 1.06G/1.19G [00:31<00:02, 54.6MB/s]
#
#
#
# gpt.pth:  37% 1.28G/3.48G [00:34<00:47, 46.5MB/s]
#
#
#
#
# qwen0.6bemo4-merge/model.safetensors:  94% 1.13G/1.19G [00:34<00:01, 40.7MB/s]
#
#
#
# gpt.pth:  39% 1.34G/3.48G [00:34<00:38, 56.1MB/s]
#
#
#
#
# qwen0.6bemo4-merge/model.safetensors: 100% 1.19G/1.19G [00:35<00:00, 33.4MB/s]
# Download complete. Moving file to /content/index-tts/checkpoints/qwen0.6bemo4-merge/model.safetensors
#
#
#
#
# gpt.pth:  41% 1.41G/3.48G [00:35<00:34, 59.6MB/s]
#
#
#
# gpt.pth:  42% 1.48G/3.48G [00:38<00:46, 43.6MB/s]
#
#
#
# gpt.pth:  44% 1.55G/3.48G [00:38<00:35, 55.3MB/s]
#
# s2mel.pth:   1% 7.00M/1.20G [00:37<1:05:32, 304kB/s]
#
#
#
# gpt.pth:  46% 1.61G/3.48G [00:39<00:28, 66.1MB/s]
#
# s2mel.pth:   1% 9.05M/1.20G [00:38<41:24, 480kB/s]
#
# s2mel.pth:   6% 76.0M/1.20G [00:38<02:05, 8.97MB/s]
#
#
#
# gpt.pth:  48% 1.68G/3.48G [00:40<00:25, 71.6MB/s]
#
#
#
# gpt.pth:  50% 1.75G/3.48G [00:42<00:35, 48.4MB/s]
#
# s2mel.pth:  12% 143M/1.20G [00:41<01:17, 13.7MB/s]
#
#
#
# gpt.pth:  52% 1.81G/3.48G [00:43<00:28, 58.2MB/s]
#
#
#
# gpt.pth:  54% 1.88G/3.48G [00:43<00:24, 65.3MB/s]
#
#
#
# gpt.pth:  56% 1.95G/3.48G [00:44<00:20, 76.7MB/s]
#
#
#
# gpt.pth:  58% 2.02G/3.48G [00:46<00:29, 50.1MB/s]
#
#
#
# gpt.pth:  60% 2.08G/3.48G [00:50<00:44, 31.5MB/s]
#
#
#
# gpt.pth:  62% 2.15G/3.48G [00:50<00:30, 43.2MB/s]
#
#
#
# gpt.pth:  64% 2.22G/3.48G [00:54<00:42, 29.6MB/s]
#
# s2mel.pth:  17% 200M/1.20G [00:53<02:11, 7.62MB/s]
#
#
#
# gpt.pth:  65% 2.28G/3.48G [00:59<00:54, 22.0MB/s]
#
#
#
# gpt.pth:  67% 2.35G/3.48G [01:00<00:39, 28.5MB/s]
#
# s2mel.pth:  22% 267M/1.20G [00:59<01:46, 8.79MB/s]
#
#
#
# gpt.pth:  69% 2.42G/3.48G [01:01<00:29, 36.2MB/s]
#
#
#
# gpt.pth:  71% 2.48G/3.48G [01:01<00:21, 47.4MB/s]
#
#
#
# gpt.pth:  73% 2.55G/3.48G [01:02<00:15, 59.5MB/s]
#
#
#
# gpt.pth:  75% 2.62G/3.48G [01:02<00:13, 65.0MB/s]
#
#
#
# gpt.pth:  77% 2.68G/3.48G [01:04<00:16, 48.8MB/s]
#
# s2mel.pth:  28% 334M/1.20G [01:04<01:23, 10.4MB/s]
#
#
#
# gpt.pth:  79% 2.75G/3.48G [01:05<00:12, 57.9MB/s]
#
#
#
# gpt.pth:  81% 2.82G/3.48G [01:06<00:09, 67.7MB/s]
#
# s2mel.pth:  33% 402M/1.20G [01:05<00:56, 14.1MB/s]
#
#
#
# gpt.pth:  83% 2.89G/3.48G [01:09<00:13, 43.4MB/s]
#
# s2mel.pth:  39% 469M/1.20G [01:08<00:44, 16.6MB/s]
#
#
#
# gpt.pth:  85% 2.95G/3.48G [01:09<00:09, 54.4MB/s]
#
# s2mel.pth:  45% 536M/1.20G [01:09<00:30, 22.0MB/s]
#
#
#
# gpt.pth:  87% 3.02G/3.48G [01:10<00:08, 56.5MB/s]
#
# s2mel.pth:  50% 603M/1.20G [01:11<00:26, 22.6MB/s]
#
# s2mel.pth:  61% 735M/1.20G [01:12<00:12, 36.9MB/s]
#
# s2mel.pth:  67% 800M/1.20G [01:13<00:08, 45.8MB/s]
#
# s2mel.pth:  72% 867M/1.20G [01:15<00:07, 43.5MB/s]
#
#
#
# gpt.pth:  88% 3.08G/3.48G [01:17<00:17, 23.2MB/s]
#
#
#
# gpt.pth:  90% 3.15G/3.48G [01:18<00:12, 27.3MB/s]
#
# s2mel.pth:  78% 934M/1.20G [01:18<00:08, 31.3MB/s]
#
# s2mel.pth:  83% 1.00G/1.20G [01:18<00:04, 42.3MB/s]
#
#
#
# gpt.pth:  92% 3.22G/3.48G [01:20<00:09, 29.2MB/s]
#
#
#
# gpt.pth:  94% 3.28G/3.48G [01:21<00:05, 38.5MB/s]
#
# s2mel.pth:  89% 1.07G/1.20G [01:22<00:04, 32.4MB/s]
#
#
#
# gpt.pth:  96% 3.35G/3.48G [01:23<00:03, 34.3MB/s]
#
#
#
# gpt.pth:  98% 3.42G/3.48G [01:24<00:01, 41.0MB/s]
#
# s2mel.pth:  94% 1.14G/1.20G [01:23<00:01, 37.1MB/s]
#
# s2mel.pth: 100% 1.20G/1.20G [01:26<00:00, 13.9MB/s]
# Download complete. Moving file to /content/index-tts/checkpoints/s2mel.pth
#
#
#
#
# gpt.pth: 100% 3.48G/3.48G [01:27<00:00, 39.8MB/s]
# Download complete. Moving file to /content/index-tts/checkpoints/gpt.pth
# Fetching 20 files: 100% 20/20 [01:28<00:00,  4.42s/it]
# /content/index-tts/checkpoints

# %%
# 为了直接利用 Gradio 的内网穿透功能
# 需要对 index—tts/webui.py 进行修改

# 如果因为 IndexTTS 官方 GitHub 仓库的更改造成本代码不可用
# 还可以手动修改 webui.py ，在 launch 函数调用中加上 `share = True`


# %cd /content/index-tts

launch_line = 'demo.launch(server_name=cmd_args.host, server_port=cmd_args.port)'
launch_line_with_share = 'demo.launch(server_name=cmd_args.host, server_port=cmd_args.port, share=True)'

with open("webui.py", encoding='utf8') as f:
  webui_with_share = []
  for line in f.readlines():
    if line.strip() == launch_line:
      webui_with_share.append(line.replace(launch_line, launch_line_with_share))
    else:
      webui_with_share.append(line)

  with open("webui_with_share.py", 'w', encoding='utf8') as f:
    f.writelines(webui_with_share)
# Out:
# /content/index-tts

# %%
# 启动

# %cd /content/index-tts/
# !uv run webui_with_share.py
# Out:
# /content/index-tts
# >> GPT weights restored from: ./checkpoints/gpt.pth
# GPT2InferenceModel has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# preprocessor_config.json: 100% 275/275 [00:00<00:00, 1.88MB/s]
# config.json: 1.87kB [00:00, 422kB/s]
# model.safetensors: 100% 2.32G/2.32G [00:32<00:00, 71.1MB/s]
# semantic_codec/model.safetensors: 100% 177M/177M [00:01<00:00, 91.1MB/s]
# >> semantic_codec weights restored from: /root/.cache/huggingface/hub/models--amphion--MaskGCT/snapshots/265c6cef07625665d0c28d2faafb1415562379dc/semantic_codec/model.safetensors
# cfm loaded
# length_regulator loaded
# gpt_layer loaded
# >> s2mel weights restored from: ./checkpoints/s2mel.pth
# campplus_cn_common.bin: 100% 28.0M/28.0M [00:00<00:00, 49.9MB/s]
# >> campplus_model weights restored from: /root/.cache/huggingface/hub/models--funasr--campplus/snapshots/fb71fe990cbf6031ae6987a2d76fe64f94377b7e/campplus_cn_common.bin
# config.json: 1.41kB [00:00, 6.89MB/s]
# Loading weights from nvidia/bigvgan_v2_22khz_80band_256x
# bigvgan_generator.pt: 100% 449M/449M [00:06<00:00, 70.4MB/s]
# Removing weight norm...
# >> bigvgan weights restored from: nvidia/bigvgan_v2_22khz_80band_256x
# 2025-09-14 15:34:04,911 WETEXT INFO building fst for zh_normalizer ...
# 2025-09-14 15:34:46,217 WETEXT INFO done
# 2025-09-14 15:34:46,217 WETEXT INFO fst path: /content/index-tts/indextts/utils/tagger_cache/zh_tn_tagger.fst
# 2025-09-14 15:34:46,217 WETEXT INFO           /content/index-tts/indextts/utils/tagger_cache/zh_tn_verbalizer.fst
# 2025-09-14 15:34:46,223 WETEXT INFO found existing fst: /content/index-tts/.venv/lib/python3.10/site-packages/tn/en_tn_tagger.fst
# 2025-09-14 15:34:46,223 WETEXT INFO                     /content/index-tts/.venv/lib/python3.10/site-packages/tn/en_tn_verbalizer.fst
# 2025-09-14 15:34:46,223 WETEXT INFO skip building fst for en_normalizer ...
# >> TextNormalizer loaded
# >> bpe model loaded from: ./checkpoints/bpe.model
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://96841ef12ee70d56ca.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Emo control mode:0,weight:0.8,vec:None
# >> starting inference...
# Use the specified emotion vector
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.53.0. You should pass an instance of `Cache` instead, e.g. `past_key_values=DynamicCache.from_legacy_cache(past_key_values)`.
# 100% 25/25 [00:11<00:00,  2.16it/s]
# torch.Size([1, 130304])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.68it/s]
# torch.Size([1, 240640])
# Use the specified emotion vector
# 100% 25/25 [00:11<00:00,  2.24it/s]
# torch.Size([1, 143104])
# Use the specified emotion vector
# 100% 25/25 [00:15<00:00,  1.62it/s]
# torch.Size([1, 270336])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.71it/s]
# torch.Size([1, 221440])
# Use the specified emotion vector
# 100% 25/25 [00:16<00:00,  1.52it/s]
# torch.Size([1, 273408])
# Use the specified emotion vector
# 100% 25/25 [00:10<00:00,  2.35it/s]
# torch.Size([1, 86272])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.70it/s]
# torch.Size([1, 239360])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.69it/s]
# torch.Size([1, 238080])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.69it/s]
# torch.Size([1, 243712])
# Use the specified emotion vector
# 100% 25/25 [00:15<00:00,  1.62it/s]
# torch.Size([1, 270336])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.71it/s]
# torch.Size([1, 229632])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.73it/s]
# torch.Size([1, 222208])
# Use the specified emotion vector
# 100% 25/25 [00:16<00:00,  1.53it/s]
# torch.Size([1, 281344])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.73it/s]
# torch.Size([1, 209152])
# Use the specified emotion vector
# 100% 25/25 [00:11<00:00,  2.26it/s]
# torch.Size([1, 121344])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.70it/s]
# torch.Size([1, 237568])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.72it/s]
# torch.Size([1, 224512])
# Use the specified emotion vector
# 100% 25/25 [00:12<00:00,  1.99it/s]
# torch.Size([1, 158720])
# Use the specified emotion vector
# 100% 25/25 [00:15<00:00,  1.62it/s]
# torch.Size([1, 265728])
# Use the specified emotion vector
# 100% 25/25 [00:10<00:00,  2.34it/s]
# torch.Size([1, 91904])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.70it/s]
# torch.Size([1, 247296])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.73it/s]
# torch.Size([1, 214272])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.73it/s]
# torch.Size([1, 212992])
# Use the specified emotion vector
# 100% 25/25 [00:10<00:00,  2.31it/s]
# torch.Size([1, 108288])
# Use the specified emotion vector
# 100% 25/25 [00:13<00:00,  1.92it/s]
# torch.Size([1, 183808])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.72it/s]
# torch.Size([1, 224512])
# Use the specified emotion vector
# 100% 25/25 [00:11<00:00,  2.22it/s]
# torch.Size([1, 139520])
# Use the specified emotion vector
# 100% 25/25 [00:15<00:00,  1.63it/s]
# torch.Size([1, 257536])
# Use the specified emotion vector
# 100% 25/25 [00:15<00:00,  1.64it/s]
# torch.Size([1, 257536])
# Use the specified emotion vector
# 100% 25/25 [00:16<00:00,  1.49it/s]
# torch.Size([1, 292352])
# Use the specified emotion vector
# 100% 25/25 [00:13<00:00,  1.91it/s]
# torch.Size([1, 184320])
# Use the specified emotion vector
# 100% 25/25 [00:13<00:00,  1.88it/s]
# torch.Size([1, 202496])
# Use the specified emotion vector
# 100% 25/25 [00:17<00:00,  1.47it/s]
# torch.Size([1, 298752])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.73it/s]
# torch.Size([1, 209408])
# Use the specified emotion vector
# 100% 25/25 [00:16<00:00,  1.52it/s]
# torch.Size([1, 273664])
# Use the specified emotion vector
# 100% 25/25 [00:16<00:00,  1.50it/s]
# torch.Size([1, 291328])
# Use the specified emotion vector
# 100% 25/25 [00:15<00:00,  1.65it/s]
# torch.Size([1, 249856])
# Use the specified emotion vector
# 100% 25/25 [00:10<00:00,  2.40it/s]
# torch.Size([1, 80384])
# Use the specified emotion vector
# 100% 25/25 [00:15<00:00,  1.64it/s]
# torch.Size([1, 260864])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.69it/s]
# torch.Size([1, 241152])
# Use the specified emotion vector
# 100% 25/25 [00:15<00:00,  1.65it/s]
# torch.Size([1, 251392])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.72it/s]
# torch.Size([1, 224512])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.73it/s]
# torch.Size([1, 221440])
# Use the specified emotion vector
# 100% 25/25 [00:16<00:00,  1.50it/s]
# torch.Size([1, 286208])
# Use the specified emotion vector
# 100% 25/25 [00:10<00:00,  2.31it/s]
# torch.Size([1, 117504])
# Use the specified emotion vector
# 100% 25/25 [00:15<00:00,  1.62it/s]
# torch.Size([1, 267264])
# Use the specified emotion vector
# 100% 25/25 [00:16<00:00,  1.52it/s]
# torch.Size([1, 279808])
# Use the specified emotion vector
# 100% 25/25 [00:09<00:00,  2.74it/s]
# torch.Size([1, 62464])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.70it/s]
# torch.Size([1, 246528])
# Use the specified emotion vector
# 100% 25/25 [00:10<00:00,  2.35it/s]
# torch.Size([1, 90112])
# Use the specified emotion vector
# 100% 25/25 [00:15<00:00,  1.62it/s]
# torch.Size([1, 270336])
# Use the specified emotion vector
# 100% 25/25 [00:11<00:00,  2.26it/s]
# torch.Size([1, 125440])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.71it/s]
# torch.Size([1, 239360])
# Use the specified emotion vector
# 100% 25/25 [00:15<00:00,  1.63it/s]
# torch.Size([1, 271872])
# Use the specified emotion vector
# 100% 25/25 [00:15<00:00,  1.62it/s]
# torch.Size([1, 271872])
# Use the specified emotion vector
# 100% 25/25 [00:11<00:00,  2.26it/s]
# torch.Size([1, 133632])
# Use the specified emotion vector
# 100% 25/25 [00:15<00:00,  1.65it/s]
# torch.Size([1, 253440])
# Use the specified emotion vector
# 100% 25/25 [00:15<00:00,  1.64it/s]
# torch.Size([1, 249856])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.69it/s]
# torch.Size([1, 245248])
# Use the specified emotion vector
# 100% 25/25 [00:11<00:00,  2.23it/s]
# torch.Size([1, 142080])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.74it/s]
# torch.Size([1, 209920])
# Use the specified emotion vector
# 100% 25/25 [00:12<00:00,  1.97it/s]
# torch.Size([1, 168448])
# Use the specified emotion vector
# 100% 25/25 [00:13<00:00,  1.90it/s]
# torch.Size([1, 192768])
# Use the specified emotion vector
# 100% 25/25 [00:12<00:00,  2.03it/s]
# torch.Size([1, 146176])
# Use the specified emotion vector
# 100% 25/25 [00:13<00:00,  1.92it/s]
# torch.Size([1, 184832])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.70it/s]
# torch.Size([1, 237312])
# Use the specified emotion vector
# 100% 25/25 [00:12<00:00,  2.01it/s]
# torch.Size([1, 151808])
# Use the specified emotion vector
# 100% 25/25 [00:13<00:00,  1.90it/s]
# torch.Size([1, 198912])
# Use the specified emotion vector
# 100% 25/25 [00:15<00:00,  1.64it/s]
# torch.Size([1, 250368])
# Use the specified emotion vector
# 100% 25/25 [00:15<00:00,  1.64it/s]
# torch.Size([1, 253952])
# Use the specified emotion vector
# 100% 25/25 [00:12<00:00,  1.95it/s]
# torch.Size([1, 180480])
# Use the specified emotion vector
# 100% 25/25 [00:15<00:00,  1.65it/s]
# torch.Size([1, 251392])
# Use the specified emotion vector
# 100% 25/25 [00:13<00:00,  1.90it/s]
# torch.Size([1, 198912])
# Use the specified emotion vector
# 100% 25/25 [00:16<00:00,  1.51it/s]
# torch.Size([1, 282880])
# Use the specified emotion vector
# 100% 25/25 [00:13<00:00,  1.91it/s]
# torch.Size([1, 186112])
# Use the specified emotion vector
# 100% 25/25 [00:16<00:00,  1.49it/s]
# torch.Size([1, 294400])
# Use the specified emotion vector
# 100% 25/25 [00:16<00:00,  1.50it/s]
# torch.Size([1, 286464])
# Use the specified emotion vector
# 100% 25/25 [00:16<00:00,  1.47it/s]
# torch.Size([1, 301824])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.71it/s]
# torch.Size([1, 240384])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.73it/s]
# torch.Size([1, 211200])
# Use the specified emotion vector
# 100% 25/25 [00:15<00:00,  1.63it/s]
# torch.Size([1, 261888])
# Use the specified emotion vector
# 100% 25/25 [00:12<00:00,  1.98it/s]
# torch.Size([1, 166400])
# Use the specified emotion vector
# 100% 25/25 [00:13<00:00,  1.90it/s]
# torch.Size([1, 198912])
# Use the specified emotion vector
# 100% 25/25 [00:15<00:00,  1.65it/s]
# torch.Size([1, 254464])
# Use the specified emotion vector
# 100% 25/25 [00:15<00:00,  1.65it/s]
# torch.Size([1, 253952])
# Use the specified emotion vector
# 100% 25/25 [00:14<00:00,  1.71it/s]
# torch.Size([1, 237568])
# Use the specified emotion vector
# 100% 25/25 [00:12<00:00,  1.95it/s]
# torch.Size([1, 168448])
# >> gpt_gen_time: 1130.76 seconds
# >> gpt_forward_time: 1.83 seconds
# >> s2mel_time: 1259.16 seconds
# >> bigvgan_time: 105.45 seconds
# >> Total inference time: 2532.18 seconds
# >> Generated audio length: 881.34 seconds
# >> RTF: 2.8731
# >> wav file saved to: outputs/spk_1757864190.wav
